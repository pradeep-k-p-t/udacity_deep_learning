# %% [markdown]
# # Introduction to Pytorch

# %%
import torch 
import numpy as np

# %%
data = [[2,3],[2,1]]
data_tensor = torch.tensor(data)
print(type(data_tensor))
# Out:
# <class 'torch.Tensor'>

# %%
data = [[2,3],[2,1]]
numpy_data = np.array(data)
data_tensor = torch.from_numpy(numpy_data)
print(type(data_tensor))
# Out:
# <class 'torch.Tensor'>

# %%
data_tensor
# Out:
# tensor([[2, 3],
#         [2, 1]])

# %%
data_tensor[:,1]
# Out:
# tensor([3, 1])

# %%
torch.ones(5,1)
# Out:
# tensor([[1.],
#         [1.],
#         [1.],
#         [1.],
#         [1.]])

# %%
torch.zeros(3,2)
# Out:
# tensor([[0., 0.],
#         [0., 0.],
#         [0., 0.]])

# %%
# generates random number between 0 and 1 
torch.rand(2,2,3)
# Out:
# tensor([[[0.1391, 0.9927, 0.6436],
#          [0.0504, 0.0793, 0.8633]],
#
#         [[0.9317, 0.6285, 0.6684],
#          [0.0293, 0.1901, 0.1899]]])

# %%
data(2,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 data(2,2)
#
# TypeError: 'list' object is not callable
